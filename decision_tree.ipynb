# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# %%capture
pip install numpy pandas matplotlib seaborn

# %%
# reading the dataset 
df=pd.read_csv("weather.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 0           0         14.0        73         9.5               82.0
# 1           2         30.0        64         7.0               16.0
# 2           3         38.0        83         1.5               82.0
# 3           4         27.0        74        17.0               66.0
# 4           9         28.0        74         8.5              107.0
#
#      Cloud Cover  Atmospheric Pressure  UV Index  Season  Visibility (km)  \
# 0  partly cloudy               1010.82         2  Winter              3.5
# 1          clear               1018.72         5  Spring              5.5
# 2          clear               1026.25         7  Spring              1.0
# 3       overcast                990.67         1  Winter              2.5
# 4          clear               1012.13         8  Winter              7.5
#
#    Location Weather Type
# 0    inland        Rainy
# 1  mountain        Sunny
# 2   coastal        Sunny
# ...

# %%
df["Weather Type"].value_counts()
# Out:
# Weather Type
# Rainy    3300
# Sunny    3300
# Name: count, dtype: int64

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind Speed', 'Precipitation (%)',
#        'Cloud Cover', 'Atmospheric Pressure', 'UV Index', 'Season',
#        'Visibility (km)', 'Location', 'Weather Type'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Temperature             0
# Humidity                0
# Wind Speed              0
# Precipitation (%)       0
# Cloud Cover             0
# Atmospheric Pressure    0
# UV Index                0
# Season                  0
# Visibility (km)         0
# Location                0
# Weather Type            0
# dtype: int64

# %%
# i want you to check for the ourliers and fix it by using capping
# season , cloud cover, Location
df["Season"].value_counts()
# Out:
# Season
# Spring    1668
# Summer    1661
# Winter    1646
# Autumn    1625
# Name: count, dtype: int64

# %%
df=pd.get_dummies(df,columns=["Cloud Cover","Season","Location"],drop_first=True, dtype=np.int64)

# %%
df.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)  Atmospheric Pressure  \
# 0         14.0        73         9.5               82.0               1010.82
# 1         30.0        64         7.0               16.0               1018.72
# 2         38.0        83         1.5               82.0               1026.25
# 3         27.0        74        17.0               66.0                990.67
# 4         28.0        74         8.5              107.0               1012.13
#
#    UV Index  Visibility (km) Weather Type  Cloud Cover_cloudy  \
# 0         2              3.5        Rainy                   0
# 1         5              5.5        Sunny                   0
# 2         7              1.0        Sunny                   0
# 3         1              2.5        Rainy                   0
# 4         8              7.5        Sunny                   0
#
#    Cloud Cover_overcast  Cloud Cover_partly cloudy  Season_Spring  \
# ...

# %%
X=df.drop(columns="Weather Type")
y=df["Weather Type"]

# %%
y.head()
# Out:
# 0    Rainy
# 1    Sunny
# 2    Sunny
# 3    Rainy
# 4    Sunny
# Name: Weather Type, dtype: object

# %%
X.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)  Atmospheric Pressure  \
# 0         14.0        73         9.5               82.0               1010.82
# 1         30.0        64         7.0               16.0               1018.72
# 2         38.0        83         1.5               82.0               1026.25
# 3         27.0        74        17.0               66.0                990.67
# 4         28.0        74         8.5              107.0               1012.13
#
#    UV Index  Visibility (km)  Cloud Cover_cloudy  Cloud Cover_overcast  \
# 0         2              3.5                   0                     0
# 1         5              5.5                   0                     0
# 2         7              1.0                   0                     0
# 3         1              2.5                   0                     1
# 4         8              7.5                   0                     0
#
# ...

# %%
# %%capture
pip install scikit-learn

# %%
# split the data into 80 and 20
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# let's train the model and test
# for tarining - X_train,y_train
# for testing - X_test for testing which gives us y_pred
# evaluation - y_test,y_pred

from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# testing
y_pred=dt.predict(X_test)

# %%
y_test
# Out:
# 4676    Rainy
# 578     Sunny
# 1362    Sunny
# 5628    Rainy
# 4045    Rainy
#         ...
# 2843    Sunny
# 5220    Sunny
# 5002    Rainy
# 5222    Sunny
# 3055    Sunny
# Name: Weather Type, Length: 1320, dtype: object

# %%
# evaluating the performance
from sklearn.metrics import accuracy_score
int(accuracy_score(y_test,y_pred)*100)
# Out:
# 94

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred2=rf.predict(X_test)

# %%
accuracy_score(y_test,y_pred2)*100
# Out:
# 94.54545454545455

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(X_train,y_train)
# Out:
# /Users/shaikmujeeburrahman/Downloads/July_ml/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred3=log.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)*100
# Out:
# 92.12121212121212

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred4=knn.predict(X_test)

# %%
accuracy_score(y_test,y_pred4)*100
# Out:
# 93.63636363636364

# %%
accuracies=[93,92,94,94]
models=["Knn","LogisticRegression","Random Forest","DecisionTreeClassifier"]

pd.DataFrame(accuracies,columns=["accuracies"],index=models)
# Out:
#                         accuracies
# Knn                             93
# LogisticRegression              92
# Random Forest                   94
# DecisionTreeClassifier          94

# %%
# your task for tomorrow is to create a gradio application on top of any of these.
# create an end to end application using tips data set and gradio
# Import the dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset("tips")

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
numerical_columns=["total_bill","size"]
categorical_columns=["sex","smoker","day","time"]
ct=ColumnTransformer(transformers=[("encoder",OneHotEncoder(),categorical_columns)],remainder="passthrough")

# %%
# separate independent variable and a dependent variable which is a tip column
X=df.drop(columns=["tip"])
y=df["tip"]

# %%
# split the dataset into train and test # hold out method
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# create the pipeline for this, which includes steps for preprocessing using column transformer and  randomforest regressor
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
pipe=Pipeline(steps=[("preprocessor",ct),("model",RandomForestRegressor())])

# %%
# Training
pipe.fit(X_train,y_train)

# %%
# gradio application

def prediction(total_bill,sex,smoker,day,time,size):
  inputs_df=pd.DataFrame([[total_bill,sex,smoker,day,time,size]],columns=["total_bill","sex","smoker","day","time","size"])
  # print(inputs_df)
  output=pipe.predict(inputs_df)
  # print(output)
  return output[0]

# %%
# %%capture
pip install gradio

# %%
# create gradio application and add dropdown for categorical variables
import gradio as gr
total_bill_input=gr.Number(label="Total Bill Amount")
gender_menu=gr.Dropdown(label="sex",choices=["Male","Female"])
smoker_menu=gr.Dropdown(label="smoker",choices=["Yes","No"])
day_menu=gr.Dropdown(label="day",choices=["Sat","Sun","Fri","Thur"])
time_menu=gr.Dropdown(label="time",choices=["Lunch","Dinner"])
size_input=gr.Number(label="Size of the family")

# %%
demo=gr.Interface(fn=prediction,inputs=[total_bill_input,gender_menu,smoker_menu,day_menu,time_menu,size_input],
                  outputs=gr.Num    ber(label="Predicted tip amount"))

# %%
demo.launch(share=True)
